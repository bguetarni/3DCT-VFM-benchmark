# %% [markdown]
# Bejarano, Tatiana, Mariluz De Ornelas‐Couto, and Ivaylo B. Mihaylov. "Longitudinal fan‐beam computed tomography dataset for head‐and‐neck squamous cell carcinoma patients."  Medical physics 46.5 (2019): 2526-2537.
#
# "Data were exported from Eclipse in DICOM (images), DICOM-RTSTRUCT (structures), and DICOM-RTDOSE (doses) format and then imported into MIM. It should be noted that we have two DICOM-RTst per imaging set, one with series description MIM structures and another named ARIA Rad Onc Structure Sets. The RTst-MIM structures was renamed by us to remain consistent with Table V structures. On the other hand, RTst-ARIA Rad Onc Structure Sets were the original structures as part of treatment planning and delivery. Our recommendation is to use RTst-MIM structures so that the information on Table V is helpful."

# %%
"""
CT and RTDOSE files can be matched based on the DICOM tag (0020,0052) Frame of Reference UID
CT and RTSTRUCT files can be matched based on the DICOM tag (0020,000d) Study Instance UID + (0008,1090) Manufacturer's Model Name
"""

# %%
import pydicom
import os, glob

path = r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT"

for patient in glob.glob(os.path.join(path, "*")):
    print(patient)
    for study in glob.glob(os.path.join(path, patient, "*")):
        print(study)
        for folder in os.listdir(study):
            try:
                dcm = pydicom.dcmread(glob.glob(os.path.join(study, folder, "*.dcm"))[0])
                if dcm.get((0x0008, 0x0060)).value == "CT":
                    print(dcm.get((0x0008, 0x0070)).value)
            except PermissionError:
                continue
# Out:
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P001
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P001\10-22-2009-NA-RTHEADNECK Adult-72945
# SIEMENS
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P001\12-08-2009-NA-RTHEADNECK Adult-25471
# SIEMENS
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P001\12-22-2009-NA-RTHEADNECK Adult-30310
# SIEMENS
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P002
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P002\08-20-2009-NA-RTHEADNECK Adult-23307
# SIEMENS
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P002\09-22-2009-NA-RTHEADNECK Adult-48638
# ---------------------------------------------------------------------------
# ...

# %%
import pydicom

dcm = pydicom.dcmread(r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P003\04-29-2010-NA-RTHEADNECK Adult-78908\140.000000-Eclipse Doses-37300\1-1.dcm")
print(dcm.get((0x0008, 0x0012)).value)
print(dcm.get((0x0008, 0x0013)).value)
print(dcm.get((0x0008, 0x0070)).value)
print(dcm.get((0x0008, 0x1090)).value)
print()

dcm = pydicom.dcmread(r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P003\04-29-2010-NA-RTHEADNECK Adult-78908\143.000000-Eclipse Doses-53687\1-1.dcm")
print(dcm.get((0x0008, 0x0012)).value)
print(dcm.get((0x0008, 0x0013)).value)
print(dcm.get((0x0008, 0x0070)).value)
print(dcm.get((0x0008, 0x1090)).value)
print()

dcm = pydicom.dcmread(r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P003\04-29-2010-NA-RTHEADNECK Adult-78908\147.000000-Eclipse Doses-55768\1-1.dcm")
print(dcm.get((0x0008, 0x0012)).value)
print(dcm.get((0x0008, 0x0013)).value)
print(dcm.get((0x0008, 0x0070)).value)
print(dcm.get((0x0008, 0x1090)).value)
# Out:
# 20160101
# 113147.981000
# Varian Medical Systems
# ARIA RadOnc
#
# 20160101
# 114329.223000
# Varian Medical Systems
# ARIA RadOnc
#
# 20160101
# 114855.256000
# Varian Medical Systems
# ARIA RadOnc

# %%
dcm = pydicom.dcmread(r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P003\04-29-2010-NA-RTHEADNECK Adult-78908\1.000000-MIM structures-86349\1-1.dcm")
dcm
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 198
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.2193.7172.315509320234378435244889586349
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20160607'
# (0008, 0013) Instance Creation Time              TM: '140447.756'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# ...

# %%
import os, glob
import pydicom

path = r"c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT"

for patient in glob.glob(os.path.join(path, "*")):
    print(patient)
    for study in glob.glob(os.path.join(patient, "*")):
        for folder in glob.glob(os.path.join(study, "*")):
            try:
                dcm = pydicom.dcmread(glob.glob(os.path.join(folder, "*"))[0])
                if dcm.get((0x0008, 0x0060)).value in ["CT", "RTDOSE", "RTSTRUCT"]:
                    print(dcm.get((0x0008, 0x0060)).value)
                    print(dcm.get((0x0008, 0x0070)).value)
                    print(dcm.get((0x0008, 0x1090)).value)
                    try:
                        print(dcm.get((0x0020, 0x0052)).value)
                    except AttributeError:
                        pass
                    try:
                        print(dcm.get((0x0020, 0x000d)).value)
                    except AttributeError:
                        pass
            except PermissionError:
                pass
            print()
# Out:
# c:\Users\bguet\Desktop\data\TCIA\HNSCC-3DCT-RT\manifest-1549495779734\HNSCC-3DCT-RT\HN_P001
# RTSTRUCT
# MIM Software Inc.
# MIM
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.847236098565581057121195872945
#
# RTSTRUCT
# Varian Medical Systems
# ARIA RadOnc
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.847236098565581057121195872945
#
# CT
# SIEMENS
# Sensation Open
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.891140827603476771527519709395
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.847236098565581057121195872945
#
# RTDOSE
# Varian Medical Systems
# ARIA RadOnc
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.891140827603476771527519709395
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.847236098565581057121195872945
#
# RTDOSE
# Varian Medical Systems
# ARIA RadOnc
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.101907709174638747667446897748
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.847236098565581057121195872945
#
# RTDOSE
# Varian Medical Systems
# ARIA RadOnc
# 1.3.6.1.4.1.14519.5.2.1.2193.7172.286380383441011852700529664753
# ...

# %%
import pickle
with open(r"C:\Users\bilel.guetarni\Desktop\SEQ-RT\data\tcia.pkl", "rb") as f:
    patients = pickle.load(f)

# %%
import pydicom

txt = ""
for p in patients:
    p.sort_imaging()
    ct = p.ct[0]
    txt += str(p.id)
    if not(ct.rtstruct is None):
        dcm = pydicom.dcmread(ct.rtstruct.get_dcm_path())
        for roi in dcm.StructureSetROISequence:
            txt += f"\n\t{roi.ROIName}"
    txt += "\n\n"

with open(r"C:\Users\bilel.guetarni\Desktop\tmp\oars.txt", "w") as file:
    file.write(txt)
